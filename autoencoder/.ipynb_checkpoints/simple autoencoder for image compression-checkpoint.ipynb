# %% [markdown]
# ![Autoencoder](../pictures/autoencoder.png)

# %% [markdown]
# #### Les autoencoders sont un type de réseaux de neurones artificiels utilisés pour effectuer une tâche d'encodage de données (representation learning).
# #### Les autoencoders utilisent les mêmes données d'entrée pour l'entrée et la sortie
# #### Les autoencoders fonctionnent en ajoutant un "bottleneck" dans le réseau. Ce "bottleneck" force le réseau à créer une version compressée (codée) de l'entrée d'origine
# #### Les autoencoders fonctionnent bien s'il existe des corrélations entre les données d'entrée (fonctionnent mal si toutes les données d'entrée sont indépendantes)

# %% [markdown]
# ### Importer les bibliothèques

# %%
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random 
import cv2
import os

# %%
print("tensorflow version:" + str(tf.__version__))
# Out:
# tensorflow version:2.3.1

# %% [markdown]
# ### Lecture d'images - Load dataset
# #### Les images sont collectées à l'aide de ma webcam, vous pouvez utiliser les images de votre choix

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.resize(cv2.cvtColor(cv2.imread(os.path.join(folder,filename)),cv2.COLOR_BGR2RGB),(100,100))
        if img is not None:
            images.append(img)
    return np.array(images)
#Assurez-vous de changer le chemin
images=load_images_from_folder('../../data/josephimg')

# %%
print(images.shape)
# Out:
# (40, 100, 100, 3)

# %%
plt.imshow(images[1])

# %% [markdown]
# ### visualisation de données

# %%
W_grid = 5
L_grid = 5

fig, axes = plt.subplots(L_grid, W_grid, figsize = (17,17))
axes = axes.ravel()
n = len(images)
for i in np.arange(0, W_grid * L_grid): 
    index = np.random.randint(0, n)
    axes[i].imshow(images[index])
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### prétraitement des données

# %%
images = images / 255

train = images[:30]
test=images[30:]

print(np.min(train))
print(np.max(train))
# Out:
# 0.08235294117647059
# 1.0

# %% [markdown]
# ### créer et former le modèle d'apprentissage en profondeur d'autoencoder

# %%
autoencoder = tf.keras.models.Sequential()

#encoder CNN
autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=(1,1), padding="same", kernel_initializer='he_uniform',
                                       input_shape=(images.shape[1], images.shape[2], images.shape[3])))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('elu'))
autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=(1,1),   
                   activation='elu', 
                   padding='same', kernel_initializer='he_uniform'))
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same"))

#decoder CNN 
autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=(1,1), padding="same",kernel_initializer='he_uniform'))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('elu'))
autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=(1,1),   
                   activation='elu', 
                   padding='same', kernel_initializer='he_uniform'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

autoencoder.add(tf.keras.layers.Conv2D(3, (3,3), strides=1, activation='sigmoid', padding="same"))

# %%
autoencoder.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(lr=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0))
autoencoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 100, 100, 64)      1792
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# activation_6 (Activation)    (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 100, 100, 64)      36928
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 50, 50, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# activation_7 (Activation)    (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 50, 50, 64)        36928
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 100, 100, 3)       1731
# =================================================================
# Total params: 114,819
# Trainable params: 114,563
# Non-trainable params: 256
# _________________________________________________________________

# %%
autoencoder.fit(train,          
          train, 
          epochs=200, 
          batch_size=5)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0219
# Epoch 2/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.0229
# Epoch 3/200
# 6/6 [==============================] - 1s 173ms/step - loss: 0.0229
# Epoch 4/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.0224
# Epoch 5/200
# 6/6 [==============================] - 1s 175ms/step - loss: 0.0218
# Epoch 6/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0213
# Epoch 7/200
# 6/6 [==============================] - 2s 260ms/step - loss: 0.0224
# Epoch 8/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0226
# Epoch 9/200
# 6/6 [==============================] - 2s 280ms/step - loss: 0.0215
# Epoch 10/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0224
# Epoch 11/200
# 6/6 [==============================] - 2s 277ms/step - loss: 0.0223
# Epoch 12/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0212
# Epoch 13/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0214
# Epoch 14/200
# 6/6 [==============================] - 2s 278ms/step - loss: 0.0208
# Epoch 15/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0214
# Epoch 16/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0210
# Epoch 17/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0208
# Epoch 18/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0210
# Epoch 19/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0208
# Epoch 20/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0218
# Epoch 21/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0219
# Epoch 22/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0204
# Epoch 23/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0202
# Epoch 24/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0203
# Epoch 25/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0204
# Epoch 26/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0201
# Epoch 27/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.0208
# Epoch 28/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0212
# Epoch 29/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0200
# Epoch 30/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0208
# Epoch 31/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0204
# Epoch 32/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0196
# Epoch 33/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0204
# Epoch 34/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0198
# Epoch 35/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0205
# Epoch 36/200
# 6/6 [==============================] - 2s 265ms/step - loss: 0.0211
# Epoch 37/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0198
# Epoch 38/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0195
# Epoch 39/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0195
# Epoch 40/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0198
# Epoch 41/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0193
# Epoch 42/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0204
# Epoch 43/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0193
# Epoch 44/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0190
# Epoch 45/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0193
# Epoch 46/200
# 6/6 [==============================] - 2s 282ms/step - loss: 0.0203
# Epoch 47/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0202
# Epoch 48/200
# 6/6 [==============================] - 2s 277ms/step - loss: 0.0200
# Epoch 49/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0201
# Epoch 50/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0193
# Epoch 51/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0191
# Epoch 52/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0187
# Epoch 53/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0197
# Epoch 54/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0194
# Epoch 55/200
# 6/6 [==============================] - 2s 322ms/step - loss: 0.0196
# Epoch 56/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0188
# Epoch 57/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0187
# Epoch 58/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0184
# Epoch 59/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0186
# Epoch 60/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0186
# Epoch 61/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0183
# Epoch 62/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0185
# Epoch 63/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0183
# Epoch 64/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0189
# Epoch 65/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0188
# Epoch 66/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0185
# Epoch 67/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0189
# Epoch 68/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0186
# Epoch 69/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0179
# Epoch 70/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0181
# Epoch 71/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0180
# Epoch 72/200
# 6/6 [==============================] - 2s 277ms/step - loss: 0.0192
# Epoch 73/200
# 6/6 [==============================] - 2s 278ms/step - loss: 0.0177
# Epoch 74/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0176
# Epoch 75/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0172
# Epoch 76/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0178
# Epoch 77/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0175
# Epoch 78/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0178
# Epoch 79/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0187
# Epoch 80/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0182
# Epoch 81/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0173
# Epoch 82/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0178
# Epoch 83/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0173
# Epoch 84/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0177
# Epoch 85/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0172
# Epoch 86/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0179
# Epoch 87/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0170
# Epoch 88/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0172
# Epoch 89/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0183
# Epoch 90/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0173
# Epoch 91/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0170
# Epoch 92/200
# 6/6 [==============================] - 2s 282ms/step - loss: 0.0180
# Epoch 93/200
# 6/6 [==============================] - 2s 283ms/step - loss: 0.0172
# Epoch 94/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0186
# Epoch 95/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0168
# Epoch 96/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0166
# Epoch 97/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0175
# Epoch 98/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0174
# Epoch 99/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0171
# Epoch 100/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0166
# Epoch 101/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0176
# Epoch 102/200
# 6/6 [==============================] - 2s 288ms/step - loss: 0.0174
# Epoch 103/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0172
# Epoch 104/200
# 6/6 [==============================] - 2s 285ms/step - loss: 0.0167
# Epoch 105/200
# 6/6 [==============================] - 2s 287ms/step - loss: 0.0162
# Epoch 106/200
# 6/6 [==============================] - 2s 318ms/step - loss: 0.0161
# Epoch 107/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.0177
# Epoch 108/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0161
# Epoch 109/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0159
# Epoch 110/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0168
# Epoch 111/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0161
# Epoch 112/200
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0161
# Epoch 113/200
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0170
# Epoch 114/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0162
# Epoch 115/200
# 6/6 [==============================] - 2s 290ms/step - loss: 0.0167
# Epoch 116/200
# 6/6 [==============================] - 2s 286ms/step - loss: 0.0188
# Epoch 117/200
# 6/6 [==============================] - 2s 287ms/step - loss: 0.0166
# Epoch 118/200
# 6/6 [==============================] - 2s 277ms/step - loss: 0.0162
# Epoch 119/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0165
# Epoch 120/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0167
# Epoch 121/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0160
# Epoch 122/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0164
# Epoch 123/200
# 6/6 [==============================] - 2s 332ms/step - loss: 0.0159
# Epoch 124/200
# 6/6 [==============================] - 2s 287ms/step - loss: 0.0154
# Epoch 125/200
# 6/6 [==============================] - 2s 282ms/step - loss: 0.0165
# Epoch 126/200
# 6/6 [==============================] - 2s 280ms/step - loss: 0.0167
# Epoch 127/200
# 6/6 [==============================] - 2s 295ms/step - loss: 0.0155
# Epoch 128/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0153
# Epoch 129/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0152
# Epoch 130/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0162
# Epoch 131/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0154
# Epoch 132/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0161
# Epoch 133/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.0153
# Epoch 134/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0156
# Epoch 135/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0154
# Epoch 136/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0157
# Epoch 137/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0160
# Epoch 138/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0160
# Epoch 139/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0151
# Epoch 140/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0152
# Epoch 141/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0148
# Epoch 142/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0153
# Epoch 143/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0158
# Epoch 144/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0151
# Epoch 145/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0173
# Epoch 146/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0147
# Epoch 147/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0147
# Epoch 148/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.0148
# Epoch 149/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0150
# Epoch 150/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0152
# Epoch 151/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0146
# Epoch 152/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0148
# Epoch 153/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0156
# Epoch 154/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0152
# Epoch 155/200
# 6/6 [==============================] - 2s 278ms/step - loss: 0.0144
# Epoch 156/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0154
# Epoch 157/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.0153
# Epoch 158/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0153
# Epoch 159/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0150
# Epoch 160/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0146
# Epoch 161/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0144
# Epoch 162/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0146
# Epoch 163/200
# 6/6 [==============================] - 2s 289ms/step - loss: 0.0140
# Epoch 164/200
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0143
# Epoch 165/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0153
# Epoch 166/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0142
# Epoch 167/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0139
# Epoch 168/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0142
# Epoch 169/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0142
# Epoch 170/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0140
# Epoch 171/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0162
# Epoch 172/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0146
# Epoch 173/200
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0139
# Epoch 174/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0139
# Epoch 175/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0141
# Epoch 176/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0148
# Epoch 177/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0138
# Epoch 178/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0137
# Epoch 179/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0144
# Epoch 180/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0137
# Epoch 181/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0150
# Epoch 182/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0142
# Epoch 183/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0139
# Epoch 184/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0145
# Epoch 185/200
# 6/6 [==============================] - 2s 272ms/step - loss: 0.0142
# Epoch 186/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0137
# Epoch 187/200
# 6/6 [==============================] - 2s 279ms/step - loss: 0.0134
# Epoch 188/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0144
# Epoch 189/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0143
# Epoch 190/200
# 6/6 [==============================] - 2s 285ms/step - loss: 0.0146
# Epoch 191/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.0139
# Epoch 192/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0134
# Epoch 193/200
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0133
# Epoch 194/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0140
# Epoch 195/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0134
# Epoch 196/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0139
# Epoch 197/200
# 6/6 [==============================] - 2s 273ms/step - loss: 0.0141
# Epoch 198/200
# 6/6 [==============================] - 2s 275ms/step - loss: 0.0138
# Epoch 199/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0132
# Epoch 200/200
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0130

# %% [markdown]
# ### Évaluer le modèle

# %%
predicted = autoencoder.predict(test)

# %%
predicted.shape
# Out:
# (10, 100, 100, 3)

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
for imgs, row in zip([test, predicted], axes):
    for img, ax in zip(imgs, row):
        ax.imshow(img)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

# %% [markdown]
# ### Les résultats ne sont pas parfaits, mais vous pouvez essayer d'améliorer les résultats en:
#
# #### 1- Apprendre sur plus de données, je n'ai utilisé que 30 images dans l'apprentissage
# #### 2- Régler les hyperparamètres
# #### 3- Essayez une meilleure architecture
